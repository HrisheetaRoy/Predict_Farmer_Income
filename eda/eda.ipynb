# %%
# Enable autoreload for development
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
# Load and clean data
from src.load_data import load_data

# %%
df = load_data()
df
# Out:
#                FarmerID           State   REGION SEX        CITY  Zipcode  \
# 0      1002818465057450  MADHYA PRADESH  CENTRAL   M      BARELI   464668
# 1      1012300674433870           BIHAR     EAST   M      BANDRA   848125
# 2      1013472263587380  MADHYA PRADESH  CENTRAL   M  MALHARGARH   458556
# 3      1019525480704050     MAHARASHTRA     WEST   M     RENAPUR   413527
# 4      1021915867444260  MADHYA PRADESH  CENTRAL   F      KHURAI   470117
# ...                 ...             ...      ...  ..         ...      ...
# 39994  8984420109139190           BIHAR     EAST   M      RAJPUR   802217
# 39995  8146998707222400           BIHAR     EAST   M      RAJPUR   802117
# 39996  9192087894978130           BIHAR     EAST   M    CHAINPUR   821102
# 39997  8544981991180050           BIHAR     EAST   M         GOH   824203
# 39998  9125435181709730           BIHAR     EAST   M      TARARI   802209
#
#                  Net     VILLAGE MARITAL_STATUS               Location  ...  \
# 0             RAISEN       Seoni              M                    NaN  ...
# 1        MUZAFFARPUR     Namapur              M                    NaN  ...
# 2           MANDSAUR     Billaud              M                    NaN  ...
# 3              LATUR     Renapur              M                    NaN  ...
# 4              SAGAR    Singhpur              M                    NaN  ...
# ...              ...         ...            ...                    ...  ...
# 39994         ROHTAS      Kadwan              M  25.3320383,84.4059833  ...
# 39995          BUXAR     Alampur              M                    NaN  ...
# 39996  KAIMUR BHABUA  Bhagwanpur              M                    NaN  ...
# 39997     AURANGABAD      Parasi              M                    NaN  ...
# 39998        BHOJPUR      Chanda              M  25.2624714,84.4637362  ...
#
#            Rabi Seasons Agro Ecological Sub Zone in 2020  \
# 0      CENTRAL HIGHLANDS (MALWA AND BUNDELKHAND)  HOT...
# 1      DECCAN PLATEAU  (TELANGANA) AND EASTERN GHATS ...
# 2      CENTRAL HIGHLANDS ( MALWA )  GUJARAT PLAIN AND...
# 3                 DECCAN PLATU  HOT SEMI-ARID ECO-REGION
# 4      CENTRAL HIGHLANDS (MALWA AND BUNDELKHAND)  HOT...
# ...                                                  ...
# 39994  CENTRAL HIGHLANDS (MALWA AND BUNDELKHAND)  HOT...
# 39995  WESTERN PLAIN  KACHCHH AND PART OF KATHIAWAR P...
# 39996  CENTRAL HIGHLANDS (MALWA AND BUNDELKHAND)  HOT...
# 39997  CENTRAL HIGHLANDS (MALWA AND BUNDELKHAND)  HOT...
# 39998             DECCAN PLATU  HOT SEMI-ARID ECO-REGION
#
#       Rabi Seasons Seasonal average groundwater thickness (cm) in 2020  \
# 0                                                  97.24
# 1                                                  73.96
# 2                                                  90.05
# 3                                                  94.64
# 4                                                  95.90
# ...                                                  ...
# 39994                                              77.01
# 39995                                              40.52
# 39996                                              98.23
# 39997                                              71.08
# 39998                                              96.58
#
#        Rabi Seasons Seasonal average groundwater replenishment rate (cm) in 2020  \
# 0                                                  19.50
# 1                                                  16.76
# 2                                                  22.44
# 3                                                  21.48
# 4                                                  18.93
# ...                                                  ...
# 39994                                              22.45
# 39995                                               1.83
# 39996                                              25.60
# 39997                                              18.56
# 39998                                              23.93
#
#         Night light index  \
# 0                    0.95
# 1                    0.97
# 2                    0.95
# 3                    0.98
# 4                    0.97
# ...                   ...
# 39994                0.97
# 39995                0.96
# 39996                0.92
# 39997                0.93
# 39998                0.98
#
#         Village score based on socio-economic parameters (Non normalised)  \
# 0                                              22.380262
# 1                                              24.630262
# 2                                              19.493313
# 3                                              31.836367
# 4                                              21.327371
# ...                                                  ...
# 39994                                          23.325668
# 39995                                          26.883697
# 39996                                          20.855222
# 39997                                          24.014604
# 39998                                          22.117889
#
#         Village score based on socio-economic parameters (0 to 100)  \
# 0                                              33.527178
# 1                                              37.173626
# 2                                              28.848462
# 3                                              48.852156
# 4                                              31.820817
# ...                                                  ...
# 39994                                          35.059345
# 39995                                          40.825642
# 39996                                          31.055631
# 39997                                          36.175865
# 39998                                          33.101964
#
#        Village category based on socio-economic parameters (Good, Average, Poor)  \
# 0                                                   Poor
# 1                                                   Poor
# 2                                                   Poor
# 3                                                Average
# 4                                                   Poor
# ...                                                  ...
# 39994                                               Poor
# 39995                                               Poor
# 39996                                               Poor
# 39997                                               Poor
# 39998                                               Poor
#
#        Land Holding Index source (Total Agri Area/ no of people)  \
# 0                                               0.773129
# 1                                               0.454140
# 2                                               0.657040
# 3                                               0.235615
# 4                                               0.207264
# ...                                                  ...
# 39994                                           0.076062
# 39995                                           0.754624
# 39996                                           0.143169
# 39997                                           0.077148
# 39998                                           0.272610
#
#         Road density (Km/ SqKm)  Target_Variable/Total Income
# 0                          0.00                       1360000
# 1                          0.00                        807200
# 2                          0.00                        500000
# 3                          2.49                        558000
# 4                          0.00                        800000
# ...                         ...                           ...
# 39994                      0.00                        712000
# 39995                      4.07                        908000
# 39996                      0.00                        498000
# 39997                      8.31                        780000
# 39998                      0.61                       1368000
#
# [39999 rows x 105 columns]
